# %%
import pandas as pd

# %%
seoul_kr = pd.read_csv('C:/Users/namgy/Downloads/서울 일반음식점(한식,53091).csv',encoding='utf-8')
seoul_jp = pd.read_csv('C:/Users/namgy/Downloads/서울 일반음식점(일식,6390).csv',encoding='utf-8')
seoul_ch = pd.read_csv('C:/Users/namgy/Downloads/서울 일반음식점(중식,4731).csv',encoding='utf-8')
seoul_etc = pd.read_csv('C:/Users/namgy/Downloads/서울 일반음식점(기타,60821).csv',encoding='utf-8')
# Out:
# C:\Users\namgy\Anaconda3\envs\python_VM3\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (25,27,28,29,30,39,41,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\namgy\Anaconda3\envs\python_VM3\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (36,41,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# seoul
# 개방자치단체코드,관리번호,인허가일자,인허가취소일자,영업상태코드,영업상태명,상세영업상태코드,상세영업상태명,폐업일자,휴업시작일자,
# 휴업종료일자,재개업일자,전화번호,소재지면적,소재지우편번호,지번주소,도로명주소,도로명우편번호,사업장명,최종수정일자,데이터갱신구분,
# 데이터갱신일자,업태구분명,좌표정보(X),좌표정보(Y),위생업태명,남성종사자수,여성종사자수,영업장주변구분명,등급구분명,급수시설구분명,
# 총인원,본사종업원수,공장사무직종업원수,공장판매직종업원수,공장생산직종업원수,건물소유구분명,보증액,월세액,다중이용업소여부,시설총규모,
# 전통업소지정번호,전통업소주된음식,홈페이지

# kyung
# 시군명,관리번호,사업장명,인허가일자,소재지도로명주소,소재지지번주소,소재지우편번호,위도,경도,인허가취소일자,통합영업상태명,영업상태명,
# 폐업일자,휴업시작일자,휴업종료일자,재개업일자,소재지시설전화번호,소재지면적정보,업태구분명정보,X좌표값,Y좌표값,위생업태명,남성종사자수,
# 여성종사자수,영업장주변구분명,등급구분명,급수시설구분명,총종업원수,본사종업원수,공장사무직종업원수,공장판매직종업원수,공장생산직종업원수,
# 건물소유구분명,보증액,월세액,다중이용업소여부,시설총규모정보,전통업소지정번호,전통업소주된음식,홈페이지URL

# %%
all_tmp = pd.read_csv('D:/Code/Muchine Learning/TensorFlow/Project/tmp.csv',encoding='utf-8')

# %%
kyung_kr.rename(columns = {'업태구분명정보' : '업태구분명'}, inplace = True)
kyung_jp.rename(columns = {'업태구분명정보' : '업태구분명'}, inplace = True)
kyung_ch.rename(columns = {'업태구분명정보' : '업태구분명'}, inplace = True)
kyung_etc.rename(columns = {'업태구분명정보' : '업태구분명'}, inplace = True)

# %%
kr = pd.concat([seoul_kr], ignore_index=True)
jp = pd.concat([seoul_jp], ignore_index=True)
ch = pd.concat([seoul_ch], ignore_index=True)
etc = pd.concat([seoul_etc], ignore_index=True)

# %%
kr = kr.fillna('')
jp = jp.fillna('')
ch = ch.fillna('')
etc = etc.fillna('')

# %%
all_tmp = all_tmp.fillna('')

# %%
all_tmp.to_csv('inn.csv', encoding='utf-8',index = False)

# %%
kr.to_csv('kr.csv', encoding = 'utf-8')
jp.to_csv('jp.csv', encoding = 'utf-8')
ch.to_csv('ch.csv', encoding = 'utf-8')
etc.to_csv('etc.csv', encoding = 'utf-8')

# %%
cafe = pd.read_csv('D:\Code\Muchine Learning\TensorFlow\Project\DB_data\cafe.csv',encoding='utf-8')
all_tmp = pd.read_csv('D:\Code\Muchine Learning\TensorFlow\Project\DB_data\\all.csv',encoding='utf-8')
inn = pd.read_csv('D:\Code\Muchine Learning\TensorFlow\Project\DB_data\inn.csv',encoding='utf-8')
# Out:
# C:\Users\namgy\Anaconda3\envs\python_VM3\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (8,13,16,17,21,22,28,37,42,43,45,46,47,50,51,52) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cafe = cafe.fillna('')
all_tmp = all_tmp.fillna('')
inn = inn.fillna('')

# %%
cafe.to_csv('cafe.csv', encoding='utf-8', index = False)
all_tmp.to_csv('all_tmp.csv', encoding='utf-8', index = False)
inn.to_csv('inn.csv', encoding='utf-8', index = False)

# %%
seoul_etc['업태구분명'].value_counts()
seoul_kr['업태구분명']
kyung_etc['업태구분명정보']

seoul = pd.concat([seoul_kr, seoul_jp, seoul_ch, seoul_etc])
kyung = pd.concat([kyung_kr, kyung_jp, kyung_ch, kyung_etc])

seoul = seoul.fillna('')
kyung = kyung.fillna('')

seoul['업태구분명'].value_counts()
kyung['업태구분명정보'].value_counts()
# Out:
# 기타                19285
# 호프/통닭             10316
# 경양식                9613
# 분식                 9136
# 통닭(치킨)             2414
# 정종/대포집/소주방         2213
# 까페                 1969
# 외국음식전문점(인도태국등)     1484
# 식육(숯불구이)            910
# 패스트푸드               682
# 김밥(도시락)             592
# 횟집                  582
# 뷔페식                 450
# 감성주점                248
# 라이브카페               201
# 패밀리레스트랑             176
# 탕류(보신용)             142
# 냉면집                 124
# 출장조리                100
# 키즈카페                 59
# 전통찻집                 55
# 복어취급                 50
# 이동조리                  6
# 커피숍                   3
# Name: 업태구분명, dtype: int64

# %%
inn = pd.read_csv('D:/Code/Muchine Learning/TensorFlow/Project/inn.csv',encoding='utf-8')
inn = inn.fillna('')

# %%
index = inn[~inn['소재지전체주소'].str.contains('서울특별시')].index

# %%
index
# Out:
# Int64Index([ 200,  201,  202,  203,  204,  205,  206,  207,  208,  209,
#             ...
#             7025, 7026, 7027, 7028, 7029, 7030, 7031, 7032, 7033, 7034],
#            dtype='int64', length=4500)

# %%
inn
# Out:
#         번호  개방자치단체코드                    관리번호   소재지우편번호  \
# 0        1   3120000  3120000-201-1997-00022  120833.0
# 1        2   3010000  3010000-201-2003-00050  100830.0
# 2        3   3230000  3230000-201-1988-00038  138827.0
# 3        4   3180000  3180000-201-2003-00007  150033.0
# 4        5   3010000  3010000-201-1968-00106  100873.0
# ...    ...       ...                     ...       ...
# 7030  7031   4050000  4050000-214-2022-00001  449930.0
# 7031  7032   4060000  4060000-201-2022-00001  413814.0
# 7032  7033   4160000  4160000-214-2022-00029  477811.0
# 7033  7034   5530000  5530000-201-2022-00005  445883.0
# 7034  7035   3980000  3980000-214-2022-00002  471815.0
#
#                                      소재지전체주소  \
# 0                       서울특별시 서대문구 창천동 20-37
# 1                     서울특별시 중구 신당동 366-101번지
# 2                       서울특별시 송파구 방이동 41-5번지
# 3                     서울특별시 영등포구 영등포동3가 24번지
# 4                     서울특별시 중구 회현동1가 127-2번지
# ...

# %%
inn.drop(index, inplace=True)

# %%
inn
# Out:
#         번호  개방자치단체코드                    관리번호   소재지우편번호  \
# 0        1   3120000  3120000-201-1997-00022  120833.0
# 1        2   3010000  3010000-201-2003-00050  100830.0
# 2        3   3230000  3230000-201-1988-00038  138827.0
# 3        4   3180000  3180000-201-2003-00007  150033.0
# 4        5   3010000  3010000-201-1968-00106  100873.0
# ...    ...       ...                     ...       ...
# 6997  6998   3010000  3010000-214-2021-00001  100281.0
# 6999  7000   3010000  3010000-214-2021-00002  100281.0
# 7012  7013   3220000  3220000-201-2022-00002  135995.0
# 7015  7016   3010000  3010000-214-2022-00001  100014.0
# 7019  7020   3180000  3180000-201-2022-00001  150862.0
#
#                        소재지전체주소                             도로명전체주소 도로명우편번호  \
# 0         서울특별시 서대문구 창천동 20-37           서울특별시 서대문구 연세로2길 50 (창천동)  3780.0
# 1       서울특별시 중구 신당동 366-101번지               서울특별시 중구 다산로 66 (신당동)  4597.0
# 2         서울특별시 송파구 방이동 41-5번지           서울특별시 송파구 올림픽로34길 5 (방이동)  5544.0
# ...

# %%
inn.to_csv('inn.csv', encoding='utf-8',index = False)
